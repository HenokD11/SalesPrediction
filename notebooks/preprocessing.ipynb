# %% [markdown]
# ## Data Preprocessing

# %%
#importing the libraries
import numpy as np
import pandas as pd
from scipy import stats
import datetime 
import plotly.express as px
import seaborn as sns
sns.set()
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn import preprocessing
import plotly.graph_objects as go
import warnings
warnings.filterwarnings("ignore")

# %%
#Adding scripts path
import sys, os
sys.path.insert(0,'../scripts/')
from data_preprocessing import data_preProcessing_script
from cleaner import DataCleaner

# %%
store_data = pd.read_csv('../data/store.csv')
train_data = pd.read_csv('../data/train.csv')
test_data = pd.read_csv('../data/test.csv')

# %%
store_data.head()
# Out:
#    Store StoreType Assortment  CompetitionDistance  CompetitionOpenSinceMonth  \
# 0      1         c          a               1270.0                        9.0
# 1      2         a          a                570.0                       11.0
# 2      3         a          a              14130.0                       12.0
# 3      4         c          c                620.0                        9.0
# 4      5         a          a              29910.0                        4.0
#
#    CompetitionOpenSinceYear  Promo2  Promo2SinceWeek  Promo2SinceYear  \
# 0                    2008.0       0              NaN              NaN
# 1                    2007.0       1             13.0           2010.0
# 2                    2006.0       1             14.0           2011.0
# 3                    2009.0       0              NaN              NaN
# 4                    2015.0       0              NaN              NaN
#
#      PromoInterval
# 0              NaN
# 1  Jan,Apr,Jul,Oct
# 2  Jan,Apr,Jul,Oct
# 3              NaN
# 4              NaN

# %%
train_data.head()
# Out:
#    Store  DayOfWeek        Date  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          5  2015-07-31   5263        555     1      1            0
# 1      2          5  2015-07-31   6064        625     1      1            0
# 2      3          5  2015-07-31   8314        821     1      1            0
# 3      4          5  2015-07-31  13995       1498     1      1            0
# 4      5          5  2015-07-31   4822        559     1      1            0
#
#    SchoolHoliday
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1

# %%
test_data.head()
# Out:
#    Id  Store  DayOfWeek        Date  Open  Promo StateHoliday  SchoolHoliday
# 0   1      1          4  2015-09-17   1.0      1            0              0
# 1   2      3          4  2015-09-17   1.0      1            0              0
# 2   3      7          4  2015-09-17   1.0      1            0              0
# 3   4      8          4  2015-09-17   1.0      1            0              0
# 4   5      9          4  2015-09-17   1.0      1            0              0

# %%
preprocess_store = data_preProcessing_script(store_data)
preprocess_store.show_data_information()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [36], line 1
# ----> 1 preprocess_store = data_preProcessing_script(store_data)
#       2 preprocess_store.show_data_information()
#
# File c:\Users\hp\SalesPrediction\notebooks\../scripts\data_preprocessing.py:20, in data_preProcessing_script.__init__(self, df)
#      18 def __init__(self, df: pd.DataFrame) -> None:
#      19     self.df = df
# ---> 20     self.logger = App_Logger(
#      21         "logs/data_preProcessing.log").get_app_logger()
#
# File c:\Users\hp\SalesPrediction\scripts\log_helper.py:14, in App_Logger.__init__(self, file_name, basic_level)
#      11 logger.setLevel(basic_level)
#      13 # define file handler and set formatter
# ---> 14 file_handler = logging.FileHandler(file_name)
#      15 formatter = logging.Formatter(
#      16     '%(asctime)s : %(levelname)s : %(name)s : %(message)s')
#      18 file_handler.setFormatter(formatter)
#
# File ~\AppData\Local\Programs\Python\Python38\lib\logging\__init__.py:1147, in FileHandler.__init__(self, filename, mode, encoding, delay)
#    1145     self.stream = None
#    1146 else:
# -> 1147     StreamHandler.__init__(self, self._open())
#
# File ~\AppData\Local\Programs\Python\Python38\lib\logging\__init__.py:1176, in FileHandler._open(self)
#    1171 def _open(self):
#    1172     """
#    1173     Open the current base file with the (original) mode and encoding.
#    1174     Return the resulting stream.
#    1175     """
# -> 1176     return open(self.baseFilename, self.mode, encoding=self.encoding)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'c:\\Users\\hp\\SalesPrediction\\notebooks\\logs\\data_preProcessing.log'
